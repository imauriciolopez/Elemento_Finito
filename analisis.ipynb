# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mat=np.array([[0.24255],[-0.01165]])
print(np.linalg.pinv(mat))
# Out:
# [[ 4.11337168 -0.19757073]]

# %%
print((np.linalg.det(mat.T@mat)))
# Out:
# 0.058966225

# %%
print(np.array([[0, 1], [0, 1]])@np.array([[0], [1]]))
# Out:
# [[1]
#  [1]]
